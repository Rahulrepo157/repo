# %% [markdown]
# # ***ENTERING THE DATA IN DATA SET***

# %%
import pandas as pd
df=pd.DataFrame({"MR":[5,5.5,6,6.5,7,8,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5],
              "CA":[0.4,0.4,0.4,0.4,0.25,0.3,0.4,0.5,0.6,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4,0.4],
              "RTIME":[60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,45,60,75,90],

                 "RTEMP":[60,60,60,60,60,60,60,60,60,60,60,45,50,60,65,65,65,65,65],
              "YEILD":[86.21,89.13,91.23,94.24,93.21,93.12,78.32,87.42,94.24,92.26,88.61,88.24,92.16,94.24,95.63,91.14,95.63,94.82,93.62]
              })

# %% [markdown]
# # ***CHECKING FIRST FIVE ROWS***

# %%
df.head()
# Out:
#     MR    CA  RTIME  RTEMP  YEILD
# 0  5.0  0.40     60     60  86.21
# 1  5.5  0.40     60     60  89.13
# 2  6.0  0.40     60     60  91.23
# 3  6.5  0.40     60     60  94.24
# 4  7.0  0.25     60     60  93.21

# %% [markdown]
# # ***CHECKING ANY NULL VALUES***:

# %%
df.isnull().sum()
# Out:
# MR       0
# CA       0
# RTIME    0
# RTEMP    0
# YEILD    0
# dtype: int64

# %% [markdown]
# # ***LOOKING AT THE STATASTICS OF DATA***

# %%
df.describe()
# Out:
#               MR         CA      RTIME  RTEMP      YEILD
# count  19.000000  19.000000  19.000000   19.0  19.000000
# mean    6.447368   0.402632  61.578947   60.0  91.235263
# std     0.574812   0.067646   8.506963    5.0   4.219831
# min     5.000000   0.250000  45.000000   45.0  78.320000
# 25%     6.500000   0.400000  60.000000   60.0  88.870000
# 50%     6.500000   0.400000  60.000000   60.0  92.260000
# 75%     6.500000   0.400000  60.000000   62.5  94.240000
# max     8.000000   0.600000  90.000000   65.0  95.630000

# %%
df
# Out:
#      MR    CA  RTIME  RTEMP  YEILD
# 0   5.0  0.40     60     60  86.21
# 1   5.5  0.40     60     60  89.13
# 2   6.0  0.40     60     60  91.23
# 3   6.5  0.40     60     60  94.24
# 4   7.0  0.25     60     60  93.21
# 5   8.0  0.30     60     60  93.12
# 6   6.5  0.40     60     60  78.32
# 7   6.5  0.50     60     60  87.42
# 8   6.5  0.60     60     60  94.24
# 9   6.5  0.40     60     60  92.26
# 10  6.5  0.40     60     60  88.61
# 11  6.5  0.40     60     45  88.24
# 12  6.5  0.40     60     50  92.16
# 13  6.5  0.40     60     60  94.24
# 14  6.5  0.40     60     65  95.63
# 15  6.5  0.40     45     65  91.14
# 16  6.5  0.40     60     65  95.63
# 17  6.5  0.40     75     65  94.82
# 18  6.5  0.40     90     65  93.62

# %% [markdown]
# # ***PLOTTING FOR YEILD(VISVALIZING YEILD)***

# %%
import matplotlib.pyplot as plt
plt.plot(df["YEILD"],label="YEILD")

# %% [markdown]
# # ***PLOTTING FOR MOLUCULAR RATIO (VISVALIZING MOLUCULAR RATIO)***

# %%
 plt.plot(df["MR"])

# %% [markdown]
# # ***VISUALIZING THE MOLUCULAR RATIO ALONG WITH YEILD***

# %%
plt.scatter(df["RTEMP"],df["YEILD"])

# %%
plt.scatter(df["RTIME"],df["YEILD"])

# %%
plt.scatter(df["CA"],df["YEILD"])

# %%
plt.scatter(df['MR'],df["YEILD"])

# %% [markdown]
# # ***BUILDING THE MACHINE LEARNING MODEL***

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # ***ACCORDING TO FORMULAE Y=MX+C ***
#
#
# # 1.   ***X=INPUT THAT IS X(MR CR RTIME RTEMP) ***
#
# ## 2.*** Y=OUTPUT THAT IS Y(YEILD)***

# %% [markdown]
# ***Multi output***

# %%
y=df[["MR","RTIME","RTEMP","CA"]]
x=df[["YEILD"]]

# %%
x=df[["MR","RTIME","RTEMP","CA"]]
y=df[["YEILD"]]

# %% [markdown]
# # ***SPLITTING THE DATA***

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      MR  RTIME  RTEMP
# 10  6.5     60     60
# 13  6.5     60     60
# 1   5.5     60     60
# 15  6.5     45     65
# 0   5.0     60     60
# 6   6.5     60     60
# 11  6.5     60     45
# 3   6.5     60     60
# 9   6.5     60     60
# 16  6.5     60     65
# 7   6.5     60     60
# 4   7.0     60     60
# 2   6.0     60     60
# 5   8.0     60     60
# 14  6.5     60     65

# %%
x_test
# Out:
#      MR  RTIME  RTEMP
# 8   6.5     60     60
# 12  6.5     60     50
# 18  6.5     90     65
# 17  6.5     75     65

# %%
y_train
# Out:
#     YEILD    CA
# 10  88.61  0.40
# 13  94.24  0.40
# 1   89.13  0.40
# 15  91.14  0.40
# 0   86.21  0.40
# 6   78.32  0.40
# 11  88.24  0.40
# 3   94.24  0.40
# 9   92.26  0.40
# 16  95.63  0.40
# 7   87.42  0.50
# 4   93.21  0.25
# 2   91.23  0.40
# 5   93.12  0.30
# 14  95.63  0.40

# %%
y_test
# Out:
#     YEILD   CA
# 8   94.24  0.6
# 12  92.16  0.4
# 18  93.62  0.4
# 17  94.82  0.4

# %%
lr=LinearRegression()

# %% [markdown]
# # ***BUILDING THE MODEL***

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
yhat=lr.predict(x_test)
print(yhat)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-148d907eb921> in <cell line: 1>()
# ----> 1 yhat=lr.predict(x_test)
#       2 print(yhat)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     352             Returns predicted values.
#     353         """
# --> 354         return self._decision_function(X)
#     355
#     356     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     335         check_is_fitted(self)
#     336
# --> 337         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...

# %%
plt.scatter(y_test,yhat)
plt.xlabel("TRUE VALUE")
plt.ylabel("PREDICTED VALUE")
# Out:
# Text(0, 0.5, 'PREDICTED VALUE')

# %%
from sklearn.metrics import r2_score
import numpy as np



# Calculate the MSEmse = np.mean((predictions - labels)**2)
mse = np.mean((yhat - y_test)**2)


print('MSE:', mse)
# Out:
# MSE: 5.828750144136132

# %%
from keras.layers import Dense
import tensorflow as tf
from keras.models import Sequential

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(46, activation='relu'),

   tf.keras.layers.Dense(32, activation='relu'),

   tf.keras.layers.Dense(32, activation='relu'),
tf.keras.layers.Dense(32, activation='relu'),
tf.keras.layers.Dense(1)])

# %%
model.compile(optimizer="adam",loss="mse")

# %% [markdown]
# model.fit(x_train,y_train,epochs=10)
#
# 1.   List item
# 2.   List item
#
#
#
# 1.   List item
# 2.   List item

# %%
model.fit(x_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 1712.3588
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1635.4568
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1563.3610
# Epoch 4/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1487.3932
# Epoch 5/100
# 1/1 [==============================] - 0s 11ms/step - loss: 1407.9518
# Epoch 6/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1331.2589
# Epoch 7/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1258.0618
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1186.5629
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1125.6052
# Epoch 10/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1067.7389
# Epoch 11/100
# 1/1 [==============================] - 0s 16ms/step - loss: 1011.9976
# Epoch 12/100
# ...

# %%
df
# Out:
#      MR    CA  RTIME  RTEMP  YEILD
# 0   5.0  0.40     60     60  86.21
# 1   5.5  0.40     60     60  89.13
# 2   6.0  0.40     60     60  91.23
# 3   6.5  0.40     60     60  94.24
# 4   7.0  0.25     60     60  93.21
# 5   8.0  0.30     60     60  93.12
# 6   6.5  0.40     60     60  78.32
# 7   6.5  0.50     60     60  87.42
# 8   6.5  0.60     60     60  94.24
# 9   6.5  0.40     60     60  92.26
# 10  6.5  0.40     60     60  88.61
# 11  6.5  0.40     60     45  88.24
# 12  6.5  0.40     60     50  92.16
# 13  6.5  0.40     60     60  94.24
# 14  6.5  0.40     60     65  95.63
# 15  6.5  0.40     45     65  91.14
# 16  6.5  0.40     60     65  95.63
# 17  6.5  0.40     75     65  94.82
# 18  6.5  0.40     90     65  93.62

# %% [markdown]
# ***Testing Set***
#
# > Indented block
#
# ---
#
#
#
# # `*   List item`
# *   List item

# %%
X_test=pd.DataFrame({"MR":[5.1,5.5,6.1,6.5,7.1,8.1,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.5,6.7],
              "CA":[0.40,0.40,0.40,0.40,0.40,0.40,0.25,0.30,0.50,0.60,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.40,0.45],
              "RTIME":[60,60,60,60,60,60,60,60,60,60,60,60,60,60,60,45,60,75,90,60],
              "RTEMP":[60,60,60,60,60,60,60,60,60,60,60,45,50,60,65,65,65,65,65,65],

              })

# %%
x_test=pd.DataFrame({"YEILD":[99,98,100]})

# %% [markdown]
# # ***Predicted yeild***

# %%
predicted_yeild=lr.predict(x_test)
print("The Predicted Yeild Is:",predicted_yeild)
# Out:
# The Predicted Yeild Is: [[ 6.92181982 69.05444754 66.14787544  0.38135485]
#  [ 6.87005828 68.02630225 65.20327642  0.38455809]
#  [ 6.97358136 70.08259282 67.09247447  0.37815162]]

# %%
df
# Out:
#      MR    CA  RTIME  RTEMP  YEILD
# 0   5.0  0.40     60     60  86.21
# 1   5.5  0.40     60     60  89.13
# 2   6.0  0.40     60     60  91.23
# 3   6.5  0.40     60     60  94.24
# 4   7.0  0.25     60     60  93.21
# 5   8.0  0.30     60     60  93.12
# 6   6.5  0.40     60     60  78.32
# 7   6.5  0.50     60     60  87.42
# 8   6.5  0.60     60     60  94.24
# 9   6.5  0.40     60     60  92.26
# 10  6.5  0.40     60     60  88.61
# 11  6.5  0.40     60     45  88.24
# 12  6.5  0.40     60     50  92.16
# 13  6.5  0.40     60     60  94.24
# 14  6.5  0.40     60     65  95.63
# 15  6.5  0.40     45     65  91.14
# 16  6.5  0.40     60     65  95.63
# 17  6.5  0.40     75     65  94.82
# 18  6.5  0.40     90     65  93.62

# %%
x_tes=pd.DataFrame({"MR":[5.1],
              "CA":[0.40],
              "RTIME":[60],
              "RTEMP":[60],

              })

# %%
predicted_yeil=lr.predict(x_tes)
print(predicted_yeil)
# Out:
# [87.73078803]

# %%
type(predicted_yeild)
# Out:
# numpy.ndarray

# %%
df["predicted_yeild"]=data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3ac4e6ba18d9> in <cell line: 1>()
# ----> 1 df["predicted_yeild"]=data2
#
# NameError: name 'data2' is not defined

# %%
df

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["YEILD"],df["predicted_yeild"])

# %% [markdown]
# ***THANK YOU***
